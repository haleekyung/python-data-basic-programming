# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 4, 9, 16, 25, 36, 49, 64]
x
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# 플롯 실행하기
plt.plot(x)

# %%
# 플롯 보여주기
plt.show(x)

# %%
# 그래프의 모양과 색 지정하기
# plt.plot(그래프 자료, 모양 + 색)

plt.plot(x, color = 'r') # 색상이 붉은색인 그래프 그리기

# %%
plt.plot(x, 'or')

# %%
plt.plot(x, 's')

# %%
# 축 이름 지정하기
x
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
y = [i for i in range(1, 9)]
y
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.plot(x, y)

# %%
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.title('matplotlib sample')
# Out:
# Text(0.5, 1.0, 'matplotlib sample')

# %%
plt.show(x)

# %%
plt.plot(x)
